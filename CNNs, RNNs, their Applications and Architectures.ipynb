# %% [markdown]
# # Different Types of Layers

# %% [markdown]
# ## Dense/ Feed-Forward Neural Network

# %%
from IPython.display import Image
Image(url= "data:image/jpeg;base64,...", width=400, height=200)
# Out:
# <img src="data:image/jpeg;base64,..." width="400" height="200"/>

# %% [markdown]
# ## Convolutional Layer

# %%
Image(url= "https://scientistcafe.com/ids/images/convolutionsbs.png", width=1000, height=600)
# Out:
# <img src="https://scientistcafe.com/ids/images/convolutionsbs.png" width="1000" height="600"/>

# %%
# With Stride
Image(url= "https://indoml.files.wordpress.com/2018/03/stride.png?w=736", width=800, height=400)
# Out:
# <img src="https://indoml.files.wordpress.com/2018/03/stride.png?w=736" width="800" height="400"/>

# %%
# With Padding
Image(url= "http://media5.datahacker.rs/2018/11/sl_1.png", width=8000, height=400)
# Out:
# <img src="http://media5.datahacker.rs/2018/11/sl_1.png" width="8000" height="400"/>

# %%
# With padding=1 and stride=2
Image(url= "https://theano-pymc.readthedocs.io/en/latest/_images/numerical_padding_strides.gif", width=700, height=400)
# Out:
# <img src="https://theano-pymc.readthedocs.io/en/latest/_images/numerical_padding_strides.gif" width="700" height="400"/>

# %%
# With multiple filters/kernals (2D Convolution Only)
Image(url= "https://miro.medium.com/max/1838/1*TT2ldUUD2JM2eSayC3i9Lw.png", width=9000, height=500)
# Out:
# <img src="https://miro.medium.com/max/1838/1*TT2ldUUD2JM2eSayC3i9Lw.png" width="9000" height="500"/>

# %%
# 3d Convolution
Image(url= "https://miro.medium.com/max/1838/1*fnkPPcqdWOtgg0ewoEfr9g.png", width=700, height=400)
# Out:
# <img src="https://miro.medium.com/max/1838/1*fnkPPcqdWOtgg0ewoEfr9g.png" width="700" height="400"/>

# %% [markdown]
# ## Pooling Layer

# %%
Image(url= "https://www.researchgate.net/profile/Hanli-Wang-2/publication/300020038/figure/fig2/AS:404961465782275@1473561745471/Toy-example-illustrating-the-drawbacks-of-max-pooling-and-average-pooling.png", width=700, height=400)
# Out:
# <img src="https://www.researchgate.net/profile/Hanli-Wang-2/publication/300020038/figure/fig2/AS:404961465782275@1473561745471/Toy-example-illustrating-the-drawbacks-of-max-pooling-and-average-pooling.png" width="700" height="400"/>

# %% [markdown]
# ## Recurrent Layers

# %%
# RNN
Image(url= "data:image/png;base64,...", width=700, height=400)
# Out:
# <img src="data:image/png;base64,..." width="700" height="400"/>

# %%
# Different ways to make RNN networks
Image(url= "https://iq.opengenus.org/content/images/2020/01/export.png", width=700, height=400)
# Out:
# <img src="https://iq.opengenus.org/content/images/2020/01/export.png" width="700" height="400"/>

# %%
# Stacking RNNs on top of each other
Image(url= "https://image.slidesharecdn.com/datasciencemeetup192f102f20171-171023084040/95/skip-residual-and-densely-connected-rnn-architectures-7-638.jpg?cb=1508748277", width=700, height=400)
# Out:
# <img src="https://image.slidesharecdn.com/datasciencemeetup192f102f20171-171023084040/95/skip-residual-and-densely-connected-rnn-architectures-7-638.jpg?cb=1508748277" width="700" height="400"/>

# %%
Image(url= "http://media5.datahacker.rs/2020/09/54-1024x547.jpg", width=700, height=400)
# Out:
# <img src="http://media5.datahacker.rs/2020/09/54-1024x547.jpg" width="700" height="400"/>

# %%
#Bidirectinal RNNs
Image(url= "https://miro.medium.com/max/764/1*6QnPUSv_t9BY9Fv8_aLb-Q.png", width=700, height=400)
# Out:
# <img src="https://miro.medium.com/max/764/1*6QnPUSv_t9BY9Fv8_aLb-Q.png" width="700" height="400"/>

# %%
# Stacked Bidirectinal RNNs
Image(url= "https://ars.els-cdn.com/content/image/1-s2.0-S0030402617316662-gr1.jpg", width=400, height=200)
# Out:
# <img src="https://ars.els-cdn.com/content/image/1-s2.0-S0030402617316662-gr1.jpg" width="400" height="200"/>

# %%
# Types of RNNs
Image(url= "https://media.springernature.com/original/springer-static/image/chp%3A10.1007%2F978-1-4842-6513-0_8/MediaObjects/501289_1_En_8_Fig5_HTML.png", width=1000, height=500)
# Out:
# <img src="https://media.springernature.com/original/springer-static/image/chp%3A10.1007%2F978-1-4842-6513-0_8/MediaObjects/501289_1_En_8_Fig5_HTML.png" width="1000" height="500"/>

# %% [markdown]
# ### LSTM

# %%
Image(url= "https://i.stack.imgur.com/aTDpS.png", width=800, height=300)
# Out:
# <img src="https://i.stack.imgur.com/aTDpS.png" width="800" height="300"/>

# %% [markdown]
# ### GRU

# %%
Image(url= "https://slidetodoc.com/presentation_image_h/080baaf45ffb427702a6bd1820b5d6dd/image-7.jpg", width=500, height=300)
# Out:
# <img src="https://slidetodoc.com/presentation_image_h/080baaf45ffb427702a6bd1820b5d6dd/image-7.jpg" width="500" height="300"/>

# %% [markdown]
# # Applications and Architectures

# %% [markdown]
# ## Dense/ Feed-Forward Neural Network

# %% [markdown]
# Fully Connected layers in a neural networks are those layers where all the inputs from one layer are connected to every activation unit of the next layer. In most popular machine learning models, the last few layers are full connected layers which compiles the data extracted by previous layers to form the final output. These can be used to perform all types of tasks.

# %% [markdown]
# ## CNNs

# %% [markdown]
# In deep learning, a convolutional neural network (CNN, or ConvNet) is a class of artificial neural network, most commonly applied to analyze visual imagery. They are also known as shift invariant or space invariant artificial neural networks (SIANN), based on the shared-weight architecture of the convolution kernels or filters that slide along input features and provide translation equivariant responses known as feature maps. Counter-intuitively, most convolutional neural networks are only equivariant, as opposed to invariant, to translation. They have applications in image and video recognition, recommender systems, image classification, image segmentation, medical image analysis, natural language processing,[6] brain-computer interfaces, and financial time series.
#
# CNNs are regularized versions of multilayer perceptrons. Multilayer perceptrons usually mean fully connected networks, that is, each neuron in one layer is connected to all neurons in the next layer. The "full connectivity" of these networks make them prone to overfitting data. Typical ways of regularization, or preventing overfitting, include: penalizing parameters during training (such as weight decay) or trimming connectivity (skipped connections, dropout, etc.) CNNs take a different approach towards regularization: they take advantage of the hierarchical pattern in data and assemble patterns of increasing complexity using smaller and simpler patterns embossed in their filters. Therefore, on a scale of connectivity and complexity, CNNs are on the lower extreme.
#
# Convolutional networks were inspired by biological processes in that the connectivity pattern between neurons resembles the organization of the animal visual cortex. Individual cortical neurons respond to stimuli only in a restricted region of the visual field known as the receptive field. The receptive fields of different neurons partially overlap such that they cover the entire visual field.
#
# CNNs use relatively little pre-processing compared to other image classification algorithms. This means that the network learns to optimize the filters (or kernels) through automated learning, whereas in traditional algorithms these filters are hand-engineered. This independence from prior knowledge and human intervention in feature extraction is a major advantage.

# %% [markdown]
# ### Common Architecures for Recognition/ Classification tasks

# %% [markdown]
# #### LeNet

# %% [markdown]
# https://en.wikipedia.org/wiki/LeNet#:~:text=LeNet%20is%20a%20convolutional%20neural,in%201989.&text=Convolutional%20neural%20networks%20are%20a,in%20large%2Dscale%20image%20processing.

# %%
Image(url= "https://cdn.analyticsvidhya.com/wp-content/uploads/2021/03/Screenshot-from-2021-03-18-12-52-17.png", width=800, height=500)
# Out:
# <img src="https://cdn.analyticsvidhya.com/wp-content/uploads/2021/03/Screenshot-from-2021-03-18-12-52-17.png" width="800" height="500"/>

# %% [markdown]
# #### AlexNet (ImageNET 2012 Winner)

# %% [markdown]
# https://en.wikipedia.org/wiki/AlexNet

# %%
Image(url= "https://neurohive.io/wp-content/uploads/2018/10/AlexNet-1.png", width=800, height=500)
# Out:
# <img src="https://neurohive.io/wp-content/uploads/2018/10/AlexNet-1.png" width="800" height="500"/>

# %% [markdown]
# #### VGGNet (ILSVRC 2014 Runner-Up)

# %% [markdown]
# https://en.everybodywiki.com/VGG_Net

# %%
Image(url= "https://www.researchgate.net/profile/Max-Ferguson/publication/322512435/figure/fig3/AS:697390994567179@1543282378794/Fig-A1-The-standard-VGG-16-network-architecture-as-proposed-in-32-Note-that-only.png", width=800, height=500)
# Out:
# <img src="https://www.researchgate.net/profile/Max-Ferguson/publication/322512435/figure/fig3/AS:697390994567179@1543282378794/Fig-A1-The-standard-VGG-16-network-architecture-as-proposed-in-32-Note-that-only.png" width="800" height="500"/>

# %% [markdown]
# #### Inception/ GoogleNet (ILSVRC 2014 Winner)

# %% [markdown]
# https://www.analyticsvidhya.com/blog/2018/10/understanding-inception-network-from-scratch/

# %%
Image(url= "https://gblobscdn.gitbook.com/assets%2F-LvMRntv-nKvtl7WOpCz%2F-LvMRp9FltcwEeVxPYFs%2F-LvMRsD3gSezT3XQmAnN%2FGoogleNet.png?alt=media", width=1000, height=600)
# Out:
# <img src="https://gblobscdn.gitbook.com/assets%2F-LvMRntv-nKvtl7WOpCz%2F-LvMRp9FltcwEeVxPYFs%2F-LvMRsD3gSezT3XQmAnN%2FGoogleNet.png?alt=media" width="1000" height="600"/>

# %%
Image(url= "http://media5.datahacker.rs/2018/11/inception_module.png", width=800, height=500)
# Out:
# <img src="http://media5.datahacker.rs/2018/11/inception_module.png" width="800" height="500"/>

# %% [markdown]
# #### ResNet(ILSVRC 2015 Winner)

# %% [markdown]
# https://www.geeksforgeeks.org/residual-networks-resnet-deep-learning/

# %%
Image(url= "https://miro.medium.com/max/1400/1*S3TlG0XpQZSIpoDIUCQ0RQ.jpeg", width=1000, height=600)
# Out:
# <img src="https://miro.medium.com/max/1400/1*S3TlG0XpQZSIpoDIUCQ0RQ.jpeg" width="1000" height="600"/>

# %%
Image(url= "data:image/png;base64,...", width=500, height=200)
# Out:
# <img src="data:image/png;base64,..." width="500" height="200"/>

# %% [markdown]
# ## Transfer Learning

# %% [markdown]
# https://en.wikipedia.org/wiki/Transfer_learning

# %% [markdown]
# ### Keras Transfer Learning Models

# %% [markdown]
# https://keras.io/api/applications/

# %% [markdown]
# ### Common Architecures for Object Detection

# %% [markdown]
# #### RCNN

# %% [markdown]
# #### Fast RCNN

# %% [markdown]
# #### Faster RCNN

# %% [markdown]
# #### YOLO

# %% [markdown]
# https://towardsdatascience.com/r-cnn-fast-r-cnn-faster-r-cnn-yolo-object-detection-algorithms-36d53571365e

# %% [markdown]
# ### Common Architecures for Object Segemtation

# %% [markdown]
# #### U-Net

# %% [markdown]
# #### Masked RCNN

# %% [markdown]
# https://medium.com/visionwizard/object-segmentation-4fc67077a678

# %% [markdown]
# ### Tensorflow Model Zoo

# %% [markdown]
# https://github.com/tensorflow/models/blob/master/research/object_detection/g3doc/tf2_detection_zoo.md

# %% [markdown]
# ## RNNs

# %% [markdown]
# https://iq.opengenus.org/applications-of-rnn/

# %% [markdown]
# ### Common Architecures for NLP/NLU Tasks

# %% [markdown]
# #### ELMo

# %% [markdown]
# https://en.wikipedia.org/wiki/ELMo

# %% [markdown]
# ### Attention is All you Need (Transformers)

# %%
Image(url= "https://cdn.analyticsvidhya.com/wp-content/uploads/2019/06/Screenshot-from-2019-06-17-19-53-10.png", width=500, height=300)
# Out:
# <img src="https://cdn.analyticsvidhya.com/wp-content/uploads/2019/06/Screenshot-from-2019-06-17-19-53-10.png" width="500" height="300"/>

# %% [markdown]
# ### Common Attention Architecures

# %% [markdown]
# #### BERT

# %% [markdown]
# https://jalammar.github.io/illustrated-bert/

# %% [markdown]
# #### GPT

# %% [markdown]
# https://jalammar.github.io/illustrated-gpt2/

# %% [markdown]
# #### T5

# %% [markdown]
# https://towardsdatascience.com/t5-text-to-text-transfer-transformer-643f89e8905e

# %% [markdown]
# ### Hugging Face Transformers

# %% [markdown]
# https://huggingface.co/models
